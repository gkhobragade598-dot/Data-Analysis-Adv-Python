# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.2'

# %%
df = pd.read_excel(r'C:\Users\gkhob\Downloads\1st, 2nd - Pandas\1st, 2nd - Pandas\Country GDP Analysis- project\data.xlsx')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
len(df) # always gives rows
# Out:
# 195

# %%
df.shape # always gives diamentions(rows and columns)
# Out:
# (195, 5)

# %%
df.columns # it will display the columns names
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
len(df.columns)
# Out:
# 5

# %%
df.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    str
#  1   CountryCode    195 non-null    str
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    str
# dtypes: float64(2), str(3)
# memory usage: 12.9 KB

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
id(df)
# Out:
# 2014871549136

# %%
df.dtypes
# Out:
# CountryName          str
# CountryCode          str
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup          str
# dtype: object

# %%
df.head() # system bydefault print top 5 rows
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
 df.tail() # bottom  5 rows
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %% [markdown]
# # indexing and slicing in pandas

# %%
df[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[:5]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df[5:10]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 5            Argentina         ARG     17.716        59.9000
# 6              Armenia         ARM     13.308        41.9000
# 7  Antigua and Barbuda         ATG     16.447        63.4000
# 8            Australia         AUS     13.200        83.0000
# 9              Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
df[3:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# 6                 Armenia         ARM     13.308           41.9
# 7     Antigua and Barbuda         ATG     16.447           63.4
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# ..                   ...
# ...

# %%
df[0:200:25]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244      78.900000          High income
# 25     Barbados         BRB     12.188      73.000000          High income
# 50      Ecuador         ECU     21.070      40.353684  Upper middle income
# 75     Honduras         HND     21.593      17.800000  Lower middle income
# 100       Libya         LBY     21.425      16.500000  Upper middle income
# 125     Namibia         NAM     29.937      13.900000  Upper middle income
# 150       Sudan         SDN     33.477      22.700000  Lower middle income
# 175     Tunisia         TUN     19.800      43.800000  Upper middle income

# %%
df[0:201:25]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244      78.900000          High income
# 25     Barbados         BRB     12.188      73.000000          High income
# 50      Ecuador         ECU     21.070      40.353684  Upper middle income
# 75     Honduras         HND     21.593      17.800000  Lower middle income
# 100       Libya         LBY     21.425      16.500000  Upper middle income
# 125     Namibia         NAM     29.937      13.900000  Upper middle income
# 150       Sudan         SDN     33.477      22.700000  Lower middle income
# 175     Tunisia         TUN     19.800      43.800000  Upper middle income

# %%
df[::10]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
df[::-50]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 194          Zimbabwe         ZWE     35.715        18.5000
# 144  French Polynesia         PYF     16.393        56.8000
# 94           Kiribati         KIR     29.044        11.5000
# 44     Czech Republic         CZE     10.200        74.1104
#
#              IncomeGroup
# 194           Low income
# 144          High income
# 94   Lower middle income
# 44           High income

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
df['CountryCode']
# Out:
# 0      ABW
# 1      AFG
# 2      AGO
# 3      ALB
# 4      ARE
#       ...
# 190    YEM
# 191    ZAF
# 192    COD
# 193    ZMB
# 194    ZWE
# Name: CountryCode, Length: 195, dtype: str

# %%
df[['BirthRate','InternetUsers']]
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
# splite the data into Catogirical data & Numerical data

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
df_cat =  df[['CountryName', 'CountryCode','IncomeGroup']]
df_cat.head(1)
# Out:
#   CountryName CountryCode  IncomeGroup
# 0       Aruba         ABW  High income

# %%
df_num = df[['BirthRate', 'InternetUsers']]
df_num.head(1)
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9

# %%
print(df.shape)
print(df_cat.shape)
print(df_num.shape)
# Out:
# (195, 5)
# (195, 3)
# (195, 2)

# %%
print(df.columns)
print()
print(df_cat.columns)
print()
print(df_num.columns)
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')
#
# Index(['CountryName', 'CountryCode', 'IncomeGroup'], dtype='str')
#
# Index(['BirthRate', 'InternetUsers'], dtype='str')

# %%
df.describe() # by default describe provide in form at numerical data only
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_num.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_cat.columns
# Out:
# Index(['CountryName', 'CountryCode', 'IncomeGroup'], dtype='str')

# %%
df_cat.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
df['InternetUsers'] <2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
 df[df['InternetUsers'] <2]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
len(df[df['InternetUsers']<2])
# Out:
# 9

# %%
df[df['BirthRate']>40]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
df[(df.BirthRate > 40) &  (df.InternetUsers <2)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df['IncomeGroup'] == 'High income'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: IncomeGroup, Length: 195, dtype: bool

# %%
df[df.IncomeGroup == 'High income']
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
df[df.IncomeGroup == 'Low income']
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 64                     Guinea         GIN     37.337           1.60
# 65                Gambia, The         GMB     42.525          14.00
# 66              Guinea-Bissau         GNB     37.503           3.10
# 77                      Haiti         HTI     25.345          10.60
# 93                   Cambodia         KHM     24.462           6.80
# ...

# %%
df['IncomeGroup'].unique()
# Out:
# <ArrowStringArray>
# ['High income', 'Low income', 'Upper middle income', 'Lower middle income']
# Length: 4, dtype: str

# %%
df['IncomeGroup'].nunique()
# Out:
# 4

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
df.columns = ['a','b','c','d','e']

# %%
df.columns = ['CountryName','CountryCode','BirthRate','InternetUser','IncomeGroup']
df.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUser  IncomeGroup
# 0        Aruba         ABW     10.244          78.9  High income
# 1  Afghanistan         AFG     35.253           5.9   Low income

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUser  \
# 0                   Aruba         ABW     10.244          78.9
# 1             Afghanistan         AFG     35.253           5.9
# 2                  Angola         AGO     45.985          19.1
# 3                 Albania         ALB     12.877          57.2
# 4    United Arab Emirates         ARE     11.044          88.0
# ..                    ...         ...        ...           ...
# 190           Yemen, Rep.         YEM     32.947          20.0
# 191          South Africa         ZAF     20.850          46.5
# 192      Congo, Dem. Rep.         COD     42.394           2.2
# 193                Zambia         ZMB     40.471          15.4
# 194              Zimbabwe         ZWE     35.715          18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.BirthRate * df.InternetUser
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
df['myCalc'] = df.BirthRate * df.InternetUser

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUser  \
# 0                 Aruba         ABW     10.244          78.9
# 1           Afghanistan         AFG     35.253           5.9
# 2                Angola         AGO     45.985          19.1
# 3               Albania         ALB     12.877          57.2
# 4  United Arab Emirates         ARE     11.044          88.0
#
#            IncomeGroup    myCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUser',
#        'IncomeGroup', 'myCalc'],
#       dtype='str')

# %%
df = df.drop('myCalc',axis = 1)

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUser',
#        'IncomeGroup'],
#       dtype='str')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUser  \
# 0                   Aruba         ABW     10.244          78.9
# 1             Afghanistan         AFG     35.253           5.9
# 2                  Angola         AGO     45.985          19.1
# 3                 Albania         ALB     12.877          57.2
# 4    United Arab Emirates         ARE     11.044          88.0
# ..                    ...         ...        ...           ...
# 190           Yemen, Rep.         YEM     32.947          20.0
# 191          South Africa         ZAF     20.850          46.5
# 192      Congo, Dem. Rep.         COD     42.394           2.2
# 193                Zambia         ZMB     40.471          15.4
# 194              Zimbabwe         ZWE     35.715          18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = 10,3

import warnings 
warnings.filterwarnings('ignore') # os error

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUser  \
# 0                 Aruba         ABW     10.244          78.9
# 1           Afghanistan         AFG     35.253           5.9
# 2                Angola         AGO     45.985          19.1
# 3               Albania         ALB     12.877          57.2
# 4  United Arab Emirates         ARE     11.044          88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df["InternetUser"]
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUser, Length: 195, dtype: float64

# %%
vis1 = sns.distplot(df["InternetUser"])

# %%
vis2 = sns.displot(df["InternetUser"])

# %%
vis3 = sns.distplot(df["InternetUser"], bins = 15)

# %%
#BOX PLOTS:
vis4 = sns.boxplot(data = df, x= "IncomeGroup" , y = 'BirthRate') #BI-VARIATE ANALYSIS

# %%
vis5 = sns.lmplot(data = df,x = 'InternetUser' , y = 'BirthRate')

# %%
vis6 = sns.lmplot(data = df,x = 'InternetUser' , y = 'BirthRate' , fit_reg = False)

# %%
vis6 = sns.lmplot(data = df,x = 'InternetUser' , y = 'BirthRate' , fit_reg = False, hue = 'IncomeGroup') # hue - parameter for color

# %%
vis6 = sns.lmplot(data = df,x = 'InternetUser' , y = 'BirthRate' , fit_reg = True, hue = 'IncomeGroup') # hue - parameter for color
