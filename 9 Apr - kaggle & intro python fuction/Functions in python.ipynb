# %%
def greet(): # greet() without argument
    print('good morning guys students very very very very lazy guys')

# %%
def greet(): # greet() without argument
print('good morning guys students very very very very lazy guys')
# Out:
#   Cell In[3], line 2
#     print('good morning guys students very very very very lazy guys')
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def greet(): # greet() without argument
    print('good morning guys students very very very very lazy guys')
greet()
# Out:
# good morning guys students very very very very lazy guys

# %%
def greet(): # greet() without argument
    print('good morning guys students very very very very lazy guys')
greet()


def greet(): # greet() without argument
    print('good morning guys students very very very very lazy guys')
greet()
# Out:
# good morning guys students very very very very lazy guys
# good morning guys students very very very very lazy guys

# %%
def greet(): # greet() without argument
    print('good morning guys students very very very very lazy guys')
    
greet()
greet()
greet()
# Out:
# good morning guys students very very very very lazy guys
# good morning guys students very very very very lazy guys
# good morning guys students very very very very lazy guys

# %%
def add(x,y): # x,y is called formal argument
   c = x + y
   print(c)
add(5,6) # 5 ^ is called actual argument
# Out:
# 11

# %%
def add(x,y): 
   c = x + y
   return c
add(5,6)
# Out:
# 11

# %%
def add(x,y): 
   c = x + y
   print(c)
    
result = add(5,6) 
print(result)
print(type(result))
# Out:
# 11
# None
# <class 'NoneType'>

# %%
def add(x,y): 
   c = x + y
   return c
    
result1 = add(5,6) 
print(result1)
print(type(result1))
# Out:
# 11
# <class 'int'>
