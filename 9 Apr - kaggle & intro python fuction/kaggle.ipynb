# %%
import pandas as pd

# %%
movies = pd.read_csv(r'C:\Users\gkhob\Downloads\archive (1)\movie.csv')

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='str')

# %%
tags = pd.read_csv(r'C:\Users\gkhob\Downloads\archive (1)\tag.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='str')

# %%
ratings = pd.read_csv(r'C:\Users\gkhob\Downloads\archive (1)\rating.csv')

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='str')

# %%
print(movies.columns)
print(tags.columns)
print(ratings.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='str')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='str')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='str')

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
print(tags.columns)
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='str')

# %%
print(ratings.columns)
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='str')

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.iloc[0]
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
tags.iloc[1]
# Out:
# userId            65
# movieId          208
# tag        dark hero
# Name: 1, dtype: object

# %%
row_0 = tags.iloc[0]
row_0
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='str')

# %%
row_0
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
print(row_0['userId'])
# Out:
# 18
