# %% [markdown]
# ## FIFA SPORT ADVANCE EDA PROJECT

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
sns.set(style="whitegrid")
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline

# %%
fifa = pd.read_csv(r'D:\22 Apr - ADV EDA PROJECTS\FIFA Sport - EDA Project\fifa.csv')

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
fifa.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  str
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  str
#  5   Nationality               18207 non-null  str
#  6   Flag                      18207 non-null  str
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  str
#  10  Club Logo                 18207 non-null  str
#  11  Value                     18207 non-null  str
#  12  Wage                      18207 non-null  str
#  13  Special                   18207 non-null  int64
#  14  Preferred Foot            18159 non-null  str
#  15  International Reputation  18159 non-null  float64
#  16  Weak Foot                 18159 non-null  float64
#  17  Skill Moves               18159 non-null  float64
#  18  Work Rate                 18159 non-null  str
#  19  Body Type                 18159 non-null  str
#  20  Real Face                 18159 non-null  str
#  21  Position                  18147 non-null  str
#  22  Jersey Number             18147 non-null  float64
#  23  Joined                    16654 non-null  str
#  24  Loaned From               1264 non-null   str
#  25  Contract Valid Until      17918 non-null  str
#  26  Height                    18159 non-null  str
#  27  Weight                    18159 non-null  str
#  28  LS                        16122 non-null  str
#  29  ST                        16122 non-null  str
#  30  RS                        16122 non-null  str
#  31  LW                        16122 non-null  str
#  32  LF                        16122 non-null  str
#  33  CF                        16122 non-null  str
#  34  RF                        16122 non-null  str
#  35  RW                        16122 non-null  str
#  36  LAM                       16122 non-null  str
#  37  CAM                       16122 non-null  str
#  38  RAM                       16122 non-null  str
#  39  LM                        16122 non-null  str
#  40  LCM                       16122 non-null  str
#  41  CM                        16122 non-null  str
#  42  RCM                       16122 non-null  str
#  43  RM                        16122 non-null  str
#  44  LWB                       16122 non-null  str
#  45  LDM                       16122 non-null  str
#  46  CDM                       16122 non-null  str
#  47  RDM                       16122 non-null  str
#  48  RWB                       16122 non-null  str
#  49  LB                        16122 non-null  str
#  50  LCB                       16122 non-null  str
#  51  CB                        16122 non-null  str
#  52  RCB                       16122 non-null  str
#  53  RB                        16122 non-null  str
#  54  Crossing                  18159 non-null  float64
#  55  Finishing                 18159 non-null  float64
#  56  HeadingAccuracy           18159 non-null  float64
#  57  ShortPassing              18159 non-null  float64
#  58  Volleys                   18159 non-null  float64
#  59  Dribbling                 18159 non-null  float64
#  60  Curve                     18159 non-null  float64
#  61  FKAccuracy                18159 non-null  float64
#  62  LongPassing               18159 non-null  float64
#  63  BallControl               18159 non-null  float64
#  64  Acceleration              18159 non-null  float64
#  65  SprintSpeed               18159 non-null  float64
#  66  Agility                   18159 non-null  float64
#  67  Reactions                 18159 non-null  float64
#  68  Balance                   18159 non-null  float64
#  69  ShotPower                 18159 non-null  float64
#  70  Jumping                   18159 non-null  float64
#  71  Stamina                   18159 non-null  float64
#  72  Strength                  18159 non-null  float64
#  73  LongShots                 18159 non-null  float64
#  74  Aggression                18159 non-null  float64
#  75  Interceptions             18159 non-null  float64
#  76  Positioning               18159 non-null  float64
#  77  Vision                    18159 non-null  float64
#  78  Penalties                 18159 non-null  float64
#  79  Composure                 18159 non-null  float64
#  80  Marking                   18159 non-null  float64
#  81  StandingTackle            18159 non-null  float64
#  82  SlidingTackle             18159 non-null  float64
#  83  GKDiving                  18159 non-null  float64
#  84  GKHandling                18159 non-null  float64
#  85  GKKicking                 18159 non-null  float64
#  86  GKPositioning             18159 non-null  float64
#  87  GKReflexes                18159 non-null  float64
#  88  Release Clause            16643 non-null  str
# dtypes: float64(38), int64(6), str(45)
# memory usage: 18.0 MB

# %%
fifa['Body Type'].value_counts()
# Out:
# Body Type
# Normal                 10595
# Lean                    6417
# Stocky                  1140
# Messi                      1
# C. Ronaldo                 1
# Neymar                     1
# Courtois                   1
# PLAYER_BODY_TYPE_25        1
# Shaqiri                    1
# Akinfenwa                  1
# Name: count, dtype: int64

# %%
f , ax = plt.subplots(figsize=(8,6))
x = fifa['Age']
ax = sns.histplot(x,bins= 10,kde=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fifa['Age']
ax = sns.distplot(x, bins = 10, vertical = True)
plt.show()
# Out:
# C:\Users\gkhob\AppData\Local\Temp\ipykernel_11404\350309578.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, bins = 10, vertical = True)

# %%
f , ax = plt.subplots(figsize=(8,6))
x = fifa['Age']
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fifa['Age']
x = pd.Series(x, name="Age variable")
ax = sns.kdeplot(x, shade= True, color= 'r')
plt.show()
# Out:
# C:\Users\gkhob\AppData\Local\Temp\ipykernel_11404\358243301.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(x, shade= True, color= 'r')

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fifa['Age']
ax = sns.displot(x, kde=False, rug=True, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = fifa['Age']
ax = sns.distplot(x,hist=False,rug=True,bins=10)
plt.show()
# Out:
# C:\Users\gkhob\AppData\Local\Temp\ipykernel_11404\3126049453.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x,hist=False,rug=True,bins=10)

# %%
fifa['Preferred Foot'].nunique()
# Out:
# 2

# %%
fifa['Preferred Foot'].value_counts()
# Out:
# Preferred Foot
# Right    13948
# Left      4211
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.countplot(x='Preferred Foot', data=fifa,color= "c")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.countplot(x='Preferred Foot', hue = "Real Face", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.countplot(y="Preferred Foot", data=fifa, color="c")
plt.show()

# %%
g = sns.catplot(x="Preferred Foot", kind="count", palette="ch:.25", data=fifa)
# Out:
# C:\Users\gkhob\AppData\Local\Temp\ipykernel_11404\4006423290.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(x="Preferred Foot", kind="count", palette="ch:.25", data=fifa)

# %%
fifa['International Reputation'].nunique()
# Out:
# 5

# %%
f,ax = plt.subplots(figsize=(8,6))
sns.stripplot(x="International Reputation", y="Potential", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.stripplot(x='International Reputation', y='Potential', data=fifa, jitter=0.01, ax=ax)
plt.show()

# %%
f,ax = plt.subplots(figsize=(8,6))
sns.stripplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fifa, jitter=0.2, palette="Set2", dodge=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.stripplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fifa, palette="Set2", size=20, marker="D", edgecolor="gray", alpha=.25)
plt.show()
# Out:
# C:\Users\gkhob\AppData\Local\Temp\ipykernel_11404\449334201.py:2: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fifa, palette="Set2", size=20, marker="D", edgecolor="gray", alpha=.25)

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.boxplot(x="International Reputation", y="Potential", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.boxplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.violinplot(x=fifa["Potential"])
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.violinplot(x="International Reputation", y="Potential", data=fifa, ax=ax)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.violinplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fifa, ax=ax)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.violinplot(x="International Reputation", y="Potential", hue="Preferred Foot",data=fifa, palette="muted", split= True)

plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.pointplot(x="International Reputation", y="Potential", data=fifa, ax=ax)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.pointplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fifa, ax=ax)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.pointplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fifa, ax=ax)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.pointplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fifa, markers=["o", "x"], linestyles=["-", "--"])
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fifa)
plt.show()

# %%
from numpy import median
f, ax = plt.subplots(figsize=(8, 6))
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa, estimator=median)
plt.show()
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa, ci=68)
plt.show()
plt.show()
# Out:
# C:\Users\gkhob\AppData\Local\Temp\ipykernel_11404\1115951860.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(x="International Reputation", y="Potential", data=fifa, ci=68)

# %%
f, ax = plt.subplots(figsize=(8, 6))
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa, ci=68)
plt.show()
plt.show()
# Out:
# C:\Users\gkhob\AppData\Local\Temp\ipykernel_11404\1115951860.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(x="International Reputation", y="Potential", data=fifa, ci=68)

# %%
f, ax = plt.subplots(figsize=(8, 6))
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa, capsize=0.2, ax=ax)
plt.show()
plt.show()

# %%
g = sns.relplot(x="Overall", y="Potential", data=fifa)

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(x="Height", y="Weight", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.lineplot(x="Stamina", y="Strength", data=fifa, ax=ax)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="Overall", y="Potential", data=fifa)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="Overall", y="Potential", data=fifa, color= "g", marker="+")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.regplot(x="International Reputation", y="Potential", data=fifa, x_jitter=.01)
plt.show()

# %%
g= sns.lmplot(x="Overall", y="Potential", data=fifa)

# %%
g= sns.lmplot(x="Overall", y="Potential", hue="Preferred Foot", data=fifa)

# %%
g= sns.lmplot(x="Overall", y="Potential", hue="Preferred Foot", data=fifa, palette="Set1")

# %%
g= sns.lmplot(x="Overall", y="Potential", col="Preferred Foot", data=fifa)

# %%
g = sns.FacetGrid(fifa, col="Preferred Foot")

# %%
g = sns.FacetGrid(fifa, col="Preferred Foot")
g = g.map(plt.hist, "Potential")

# %%
g = sns.FacetGrid(fifa, col="Preferred Foot")
g = g.map(plt.hist, "Potential", bins=10, color="r")

# %%
g = sns.FacetGrid(fifa, col="Preferred Foot")
g = (g.map(plt.scatter, "Height", "Weight", edgecolor="w").add_legend())

# %%
g = sns.FacetGrid(fifa, col="Preferred Foot", height=5, aspect=1)
g = g.map(plt.hist, "Potential")

# %%
fifa_new = fifa[['Age', 'Potential', 'Strength', 'Stamina', 'Preferred Foot']]

# %%
g = sns.PairGrid(fifa_new)
g = g.map(plt.scatter)

# %%
g = sns.PairGrid(fifa_new)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
g = sns.PairGrid(fifa_new, hue="Preferred Foot")
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
g = sns.PairGrid(fifa_new, hue="Preferred Foot")
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
g = sns.PairGrid(fifa_new, vars=['Age', 'Stamina'])
g = g.map(plt.scatter)

# %%
g = sns.PairGrid(fifa_new)
g = g.map_upper(plt.scatter)
g = g.map_lower(sns.kdeplot, cmap="Blues_d")
g = g.map_diag(sns.kdeplot, lw=3, legend=False)

# %%
g = sns.JointGrid(x="Overall", y="Potential", data=fifa)
g = g.plot(sns.regplot, sns.distplot)
# Out:
# c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\axisgrid.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(self.x, **orient_kw_x, **kwargs)
# c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\axisgrid.py:1892: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(self.y, **orient_kw_y, **kwargs)

# %%
import matplotlib.pyplot as plt

# %%
g = sns.JointGrid(x="Overall", y="Potential", data=fifa)
g = g.plot_joint(plt.scatter, color=".5", edgecolor="white")
g = g.plot_marginals(sns.distplot, kde=False, color=".5")
# Out:
# c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\axisgrid.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(self.x, **orient_kw_x, **kwargs)
# c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\axisgrid.py:1892: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(self.y, **orient_kw_y, **kwargs)

# %%
g = sns.JointGrid(x="Overall", y="Potential", data=fifa, space=0)
g = g.plot_joint(sns.kdeplot, cmap="Blues_d")
g = g.plot_marginals(sns.kdeplot, shade=True)
# Out:
# c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\axisgrid.py:1883: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, ax=self.ax_marg_x, **kwargs)
# c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\axisgrid.py:1889: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(y=self.y, ax=self.ax_marg_y, **kwargs)

# %%
g = sns.JointGrid(x="Overall", y="Potential", data=fifa, height=5, ratio=2)
g = g.plot_joint(sns.kdeplot, cmap="Reds_d")
g = g.plot_marginals(sns.kdeplot, color="r", shade=True)
# Out:
# c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\axisgrid.py:1883: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, ax=self.ax_marg_x, **kwargs)
# c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\axisgrid.py:1889: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(y=self.y, ax=self.ax_marg_y, **kwargs)

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="Overall", y="Potential", data=fifa);

# %%
sns.lmplot(x="Overall", y="Potential", col="Preferred Foot", data=fifa, col_wrap=2, height=5, aspect=1)

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
sinplot()

# %%
sns.set()
sinplot()

# %%
sns.set_style("whitegrid")
sinplot()

# %%
sns.set_style("dark")
sinplot()

# %%
sns.set_style("white")
sinplot()

# %%
sns.set_style("ticks")
sinplot()
